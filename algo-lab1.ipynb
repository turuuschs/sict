# %% [markdown]
# <a href="https://colab.research.google.com/github/turuuschs/sict/blob/master/algo-lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторийн ажил-1

# %% [markdown]
# ## Ашиглах сан

# %%
import math
import os
import random
import re
import sys

# %% [markdown]
# ## Бодлогын даалгаврыг гүйцээсэн функц

# %%
def hurdleRace(k, height):
    mx_height = 0
    for h in height:
        mx_height = max(mx_height, h)
    if k >= mx_height:
        return 0
    else:
        return mx_height - k

# %% [markdown]
# ## Үндсэн функц

# %%
if __name__ == '__main__':
 fptr = open(os.environ['OUTPUT_PATH'], 'w')
 nk = input().split()
 n = int(nk[0])
 k = int(nk[1])
 height = list(map(int, input().rstrip().split()))
 result = hurdleRace(k, height)
 fptr.write(str(result) + '\n')
 fptr.close()

# %% [markdown]
# # Hackerrank дээрх үр дүн
# ![Screen Shot 2020-09-22 at 14.41.51.png](data:image/png;base64,...)
